# %% [markdown]
# <a href="https://colab.research.google.com/github/ekulbiene/augintinis/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vardas = input("Koks tavo vardas")
amzius = int(input("Kiek tau metų?"))
metai = 2026 - amzius
print("Labas, ", vardas, ", tu gimei", metai, "metais.")
# Out:
# Koks tavo vardasDomas
# Kiek tau metų?14
# Labas,  Domas , tu gimei 2012 metais.
